# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuuTsubaki/fitting-random-labels/blob/master/cifar100_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/
# !ls
# Out:
#  cifar100_1.txt    'Colab Notebooks'	    model_mlp.py	  test.py
#  cifar100_data.py   Fashion_MNIST_data.py   model_wideresnet.py   train.py
#  cifar10_1.txt	    imagenet_data.py	    plot.py		  VOC_data.py
#  cifar10_data.py    kmnist_data.py	    README.md
#  cmd_args.py	    LICENSE		    stl10_data.py
# gdrive	sample_data

# %%
# !cp -r /content/gdrive/My\ Drive/* ./

# %%
! python train.py --label-corrupt-prob=0.5 --data=cifar100 --num-classes=100
# Out:
# Namespace(arch='wide-resnet', batch_size=128, command='train', data='cifar100', data_augmentation=False, epochs=300, eval_full_trainset=True, exp_name='cifar100_corrupt0.5_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug', label_corrupt_prob=0.5, learning_rate=0.1, mlp_spec='512', momentum=0.9, name='', num_classes=100, weight_decay=0.0001, wrn_depth=28, wrn_droprate=0.0, wrn_widen_factor=1)
# Logging into runs/cifar100_corrupt0.5_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug...
# ...
# 100% 168763392/169001437 [01:08<00:00, 3488914.49it/s]Number of parameters: 375348
# 169009152it [01:20, 3488914.49it/s]                   train.py:382: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = torch.autograd.Variable(input, volatile=True)
# train.py:383: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   target_var = torch.autograd.Variable(target, volatile=True)
# ...
