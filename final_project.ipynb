# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuuTsubaki/fitting-random-labels/blob/master/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls /content/gdrive/My\ Drive/Spring2019/CS\ 4284/random-labels-given-other-neutral-network
# !ls
# Out:
# cifar10_data.py  LICENSE       model_wideresnet.py  train.py
# cmd_args.py	 model_mlp.py  README.md
# cifar10_data.py  gdrive        model_wideresnet.py  runs
# cmd_args.py	 LICENSE       __pycache__	    sample_data
# data		 model_mlp.py  README.md	    train.py

# %%
# !cp -r /content/gdrive/My\ Drive/Spring2019/CS\ 4284/random-labels-given-other-neutral-network/* ./

# %%
! python train.py

# %%
# !python train.py --label-corrupt-prob=0.5

# %%
# !python train.py --label-corrupt-prob=1.0

# %%
# !python train.py --data=cifar100 --num-classes=100
# Out:
# Namespace(arch='wide-resnet', batch_size=128, command='train', data='cifar100', data_augmentation=False, epochs=300, eval_full_trainset=True, exp_name='cifar100_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug', label_corrupt_prob=0.0, learning_rate=0.1, mlp_spec='512', momentum=0.9, name='', num_classes=100, weight_decay=0.0001, wrn_depth=28, wrn_droprate=0.0, wrn_widen_factor=1)
# Logging into runs/cifar100_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug...
# ...
# 100% 168837120/169001437 [00:58<00:00, 2479013.49it/s]Number of parameters: 375348
# 169009152it [01:10, 2479013.49it/s]                   train.py:382: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = torch.autograd.Variable(input, volatile=True)
# train.py:383: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   target_var = torch.autograd.Variable(target, volatile=True)
# ...

# %%
# !python train.py --label-corrupt-prob=0.5 --data=cifar100 --num-classes=100

# %%
# !python train.py --label-corrupt-prob=1.0 --data=cifar100 --num-classes=100
# Out:
# Namespace(arch='wide-resnet', batch_size=128, command='train', data='cifar100', data_augmentation=False, epochs=300, eval_full_trainset=True, exp_name='cifar100_corrupt1_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug', label_corrupt_prob=1.0, learning_rate=0.1, mlp_spec='512', momentum=0.9, name='', num_classes=100, weight_decay=0.0001, wrn_depth=28, wrn_droprate=0.0, wrn_widen_factor=1)
# Logging into runs/cifar100_corrupt1_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug...
# Files already downloaded and verified
# Number of parameters: 375348
# train.py:259: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = torch.autograd.Variable(input, volatile=True)
# train.py:260: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   target_var = torch.autograd.Variable(target, volatile=True)
# 000: Acc-tr:  12.49, Acc-val:  11.81, L-tr: 3.6397, L-val: 3.6806
# ...
