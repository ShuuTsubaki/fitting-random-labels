# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuuTsubaki/fitting-random-labels/blob/master/cifar100_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls /content/gdrive/My\ Drive/random_labels
# Out:
#  cifar100_1.txt     Fashion_MNIST_data.py   model_wideresnet.py   train.py
#  cifar100_data.py   imagenet_data.py	    plot.py		  VOC_data.py
#  cifar10_1.txt	    kmnist_data.py	   'README (1).md'
#  cifar10_data.py    LICENSE		    stl10_data.py
#  cmd_args.py	    model_mlp.py	    test.py

# %%
# !cp -r /content/gdrive/My\ Drive/random_labels/* ./
# !ls
# Out:
#  cifar100_1.txt     Fashion_MNIST_data.py   model_mlp.py	  stl10_data.py
#  cifar100_data.py   gdrive		    model_wideresnet.py   test.py
#  cifar10_1.txt	    imagenet_data.py	    plot.py		  train.py
#  cifar10_data.py    kmnist_data.py	   'README (1).md'	  VOC_data.py
#  cmd_args.py	    LICENSE		    sample_data

# %%
! python train.py --data=cifar100 --num-classes=100
# Out:
# Namespace(arch='wide-resnet', batch_size=128, command='train', data='cifar100', data_augmentation=False, epochs=300, eval_full_trainset=True, exp_name='cifar100_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug', label_corrupt_prob=0.0, learning_rate=0.1, mlp_spec='512', momentum=0.9, name='', num_classes=100, weight_decay=0.0001, wrn_depth=28, wrn_droprate=0.0, wrn_widen_factor=1)
# Logging into runs/cifar100_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug...
# ...
# 100% 168837120/169001437 [00:58<00:00, 2479013.49it/s]Number of parameters: 375348
# 169009152it [01:10, 2479013.49it/s]                   train.py:382: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = torch.autograd.Variable(input, volatile=True)
# train.py:383: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   target_var = torch.autograd.Variable(target, volatile=True)
# ...
