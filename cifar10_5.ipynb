# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuuTsubaki/fitting-random-labels/blob/master/cifar10_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls
# Out:
# CIFAR100data	  data		model_wideresnet.py  sample_data    train.py
# cifar100_data.py  gdrive	__pycache__	     STL100data
# cifar10_data.py   LICENSE	README.md	     stl10_data.py
# cmd_args.py	  model_mlp.py	runs		     test.py

# %%
# !python train.py --label-corrupt-prob=0.5
# Out:
# Namespace(arch='wide-resnet', batch_size=128, command='train', data='cifar10', data_augmentation=False, epochs=300, eval_full_trainset=True, exp_name='cifar10_corrupt0.5_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug', label_corrupt_prob=0.5, learning_rate=0.1, mlp_spec='512', momentum=0.9, name='', num_classes=10, weight_decay=0.0001, wrn_depth=28, wrn_droprate=0.0, wrn_widen_factor=1)
# Logging into runs/cifar10_corrupt0.5_wide-resnet28-1_lr0.1_mmt0.9_Wd0.0001_NoAug...
# Files already downloaded and verified
# Number of parameters: 369498
# train.py:259: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = torch.autograd.Variable(input, volatile=True)
# train.py:260: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   target_var = torch.autograd.Variable(target, volatile=True)
# 000: Acc-tr:  58.58, Acc-val:  57.12, L-tr: 1.1676, L-val: 1.2036
# ...
